# %% [markdown]
# Features are load, weather (tmax, tmin, precipitation), days since last planned outage, days since last maintenance outage, month

# %%
using Printf, CSV, DataFrames, Statistics, Glob, XLSX, Dates, Plots, TimeSeries, JSON

# %%
data_directory = joinpath("/projects", "emco4286", "data", "gads", "raw_data")
files = glob("gen_*_type_*_dtgrp_*_rating_*_state_Texas_raw.csv", data_directory)
# Out:
# 604-element Vector{String}:
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_5_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_2_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_2_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_2_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_3_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  ⋮
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_2_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_4_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_3_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_3_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_3_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_1_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_1_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_1_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_4_rating_1_state_Texas_raw.csv"

# %%
dict_directory = joinpath(homedir(), "gads-analysis", "nerc_to_sienna.json")
nerc_to_sienna = JSON.parsefile(dict_directory)
nerc_types = [match(r"type_(\d*)_", f)[1] for f in files]
idx = filter(x -> nerc_to_sienna[nerc_types[x]] == 4, collect(1:1:length(files)))
files = files[idx]
# Out:
# 264-element Vector{String}:
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_2_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_2_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_2_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_3_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 31 bytes ⋯ "_4_rating_1_state_Texas_raw.csv"
#  ⋮
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_2_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_4_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_3_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_3_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_3_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_1_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_1_rating_1_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_1_rating_2_state_Texas_raw.csv"
#  "/projects/emco4286/data/gads/ra" ⋯ 30 bytes ⋯ "_4_rating_1_state_Texas_raw.csv"

# %%
fname = "ercot_hourly_load_2013_2023.csv"
path = joinpath("/projects", "emco4286", "data", "ercot", fname)
load_data = DataFrame(CSV.File(path))
DataFrames.rename!(load_data, :Hour_End => "x")

load_data = load_data[!, [:x, :ERCOT]]
# Out:
# 96408×2 DataFrame
#    Row │ x                    ERCOT
#        │ DateTime             Float64
# ───────┼──────────────────────────────
#      1 │ 2013-01-01T01:00:00  28684.9
#      2 │ 2013-01-01T02:00:00  28002.7
#      3 │ 2013-01-01T03:00:00  27363.8
#      4 │ 2013-01-01T04:00:00  27032.4
#      5 │ 2013-01-01T05:00:00  27163.8
#      6 │ 2013-01-01T06:00:00  27836.8
#      7 │ 2013-01-01T07:00:00  28722.0
#      8 │ 2013-01-01T08:00:00  29391.7
#    ⋮   │          ⋮              ⋮
#  96402 │ 2023-12-31T18:00:00  44391.8
#  96403 │ 2023-12-31T19:00:00  45677.1
#  96404 │ 2023-12-31T20:00:00  44751.2
#  96405 │ 2023-12-31T21:00:00  43892.8
#  96406 │ 2023-12-31T22:00:00  43113.7
#  96407 │ 2023-12-31T23:00:00  42244.6
#  96408 │ 2024-01-01T00:00:00  41622.0
#                     96393 rows omitted

# %%
weather_pt = joinpath("/projects", "emco4286", "data", "noaa", "processed")
weather_files = glob("*.csv", weather_pt)

my_w_list = []

for w in weather_files

    # types_dict=Dict(("Column1" => DateTime))
    weather = DataFrame(CSV.File(w)) #, dateformat="yyyy-mm-dd HH:00:00"))
    weather.Column1 = DateTime.(weather.Column1, "yyyy-mm-dd HH:00:00")
    push!(my_w_list, weather)
end

weather_merged = reduce((x, y) -> innerjoin(x, y, on=:Column1), my_w_list)
DataFrames.rename!(weather_merged, :Column1 => :x)
bool_vec = weather_merged.Tmax .== 0
bool_vec = ifelse.(ismissing.(bool_vec), 0, bool_vec)
bool_vec = convert.(Bool, bool_vec)
idx1 = filter(r -> bool_vec[r], range(1, length(bool_vec)))
weather_merged[idx1, :Tmax] .= missing;

# %%
x = Dict()
i = 1
mydict = Dict([("A", 1), ("RS", 1), ("NC", 1),  ("IR", 1), ("MB", 1), ("F", 2), ("U1", 2), ("U2" , 2), ("U3" , 2), ("D1", 2), ("D2", 2), ("D3", 2), ("SF", 2), ("PO", 3), ("PE", 3), ("PD", 3), ("DP", 3), ("MO", 4), ("ME", 4), ("DM", 4), ("D4", 4), ("RU", 5), ("DR", 5), ("TC", 5)])
agedict = Dict([(1, DateTime(1980, 1, 1)), (2, DateTime(1985, 1, 1)), (3, DateTime(1995, 1, 1)), (4, DateTime(2005, 1, 1)), (5, DateTime(2015, 1, 1)), (6, DateTime(2020, 1, 1))])
# agedict = Dict([(2, DateTime(1989, 1, 1)), (3, DateTime(1993, 1, 1))])
types_dict = Dict("EventStartDT" => DateTime, "EventEndDT" => DateTime)
rating_dict = Dict([(1, 50), (2, 150), (3, 200)]);
# weather_zone_dict = Dict([(2, "COAST"), (3, "NORTH_C")]);
# Out:
# Dict{Int64, Int64} with 3 entries:
#   2 => 150
#   3 => 200
#   1 => 50

# %%
start_date_g = DateTime(2013,1,1,6)
end_date_g = DateTime(2024,1,1,6)
date_range_g = [k for k in start_date_g:Hour(1):end_date_g]

myrange_g = [k for k in 0:1:round(end_date_g - start_date_g, Hour).value]

for f in files

    @printf "%s \n" f

    mymatch = match(r"/projects/emco4286/data/gads/raw_data/gen_(\d+)_type_(\d+)_dtgrp_(\d+)_rating_(\d+)_state_Texas_raw.csv", f)
    id = parse(Int32, mymatch[1])
    rating = parse(Int32, mymatch[4])

    df = DataFrame(CSV.File(f, types=types_dict))
    df = df[typeof.(df.EventEndDT) .== DateTime, :] # for missing DateTime values
    df = df[df.EventTypeCode .!= "RS", :]

    if size(df)[1] > 1

        sort!(df, :EventStartDT)
        transform!(df, :EventTypeCode => ByRow(x -> mydict[x]), :EventTypeCode)
        df = df[df.EventTypeCode_function .!= 5, :]
        df = df[df.EventTypeCode_function .!= 1, :]

        if size(df)[1] > 1

            birthdate = agedict[df[1, :CommercialDT_grp]]

            # 
            state = convert(Array{Union{Missing, Float64}}, fill(1, length(myrange_g))) # to allow missing values
            cause = convert(Array{Union{Missing, Float64}}, fill(1, length(myrange_g)))
            rating_array = convert(Array{Union{Missing, Float64}}, fill(rating, length(myrange_g)))
            age = [k.value for k in round.(date_range_g - birthdate, Day(1))]


            # Hour that outage starts
            time_vector = map(x -> round(x - start_date_g, Hour), df[!, :EventStartDT])

            # Set state to zero during an event
            for k in [c for c in range(1, step=1, length=length(time_vector))] # k is an index
                start_time_string = round(df[k, :EventStartDT], Hour)
                end_time_string = round(df[k, :EventEndDT], Hour)

                mycause = df[k, :EventTypeCode_function]

                # if cause == 1 # RS
                #     continue
                # end

                start_hour = time_vector[k].value # integer
                duration = round(end_time_string - start_time_string, Hour).value
                end_hour = start_hour + duration

                start_index = max(1, start_hour)

                matching_idx = findall(x -> x == end_hour, myrange_g)
                
                if length(matching_idx) < 1
                    end_index = length(state)
                else
                    end_index = matching_idx[1]
                end

                # If event is unit getting retired, set state as missing until the end of the period and skip to the next unit
                if mycause == 5
                    state[start_index:end] .= missing
                    cause[start_index:end] .= missing
                else
                    state[start_index:end_index] .= 0
                    cause[start_index:end_index] .= mycause
                end

            end

            trajectory = DataFrame(x=date_range_g, y1=state, y2=cause, y3=age, y9=rating_array)
            mask = map(x -> ismissing(x) ? false : true, trajectory.y2)
            trajectory = trajectory[mask, :]

            merged = innerjoin(trajectory, load_data[!,[:x, :ERCOT]], on=:x)
            sort!(merged, :x)
            merged[!, :y4] = Dates.dayofyear.(merged[!, :x])

            # Add weather, deal with Tmax = 0
            merged = innerjoin(merged, weather_merged, on=:x)

            # Days since last planned outage
            my_data = Vector{Union{Int,Missing}}(missing, length(merged[!, :x]))

            indexed = merged[merged.y2 .== 3, :]
            bool_vec = diff(indexed[!, :x]) .!= Millisecond(3600000)

            idx1 = filter(r -> bool_vec[r], range(1, length(bool_vec)))
            event_end_datetimes = indexed[idx1, :x]

            k = 1
            for i in merged[!, :x]

                events_before_i = [k for k in event_end_datetimes if k < i]

                if length(events_before_i) < 1
                    my_data[1:k] .= missing
                else


                    val, idx2 = findmin(i .- events_before_i)
                    closest_event = event_end_datetimes[idx2]
                    hours_since_event = round(i - closest_event, Day).value

                    my_data[k] = hours_since_event
                end

                k+= 1
            end

            merged[!, :y6] = my_data

            # Days since last maintenance outage
            my_data = Vector{Union{Int,Missing}}(missing, length(merged[!, :x]))

            indexed = merged[merged.y2 .== 4, :]
            bool_vec = diff(indexed[!, :x]) .!= Millisecond(3600000)

            idx1 = filter(r -> bool_vec[r], range(1, length(bool_vec)))
            event_end_datetimes = indexed[idx1, :x]

            k = 1
            for i in merged[!, :x]

                events_before_i = [k for k in event_end_datetimes if k < i]

                if length(events_before_i) < 1
                    my_data[1:k] .= missing
                else
                    val, idx2 = findmin(i .- events_before_i)
                    closest_event = event_end_datetimes[idx2]
                    hours_since_event = round(i - closest_event, Day).value

                    my_data[k] = hours_since_event
                end

                k+= 1
            end

            merged[!, :y7] = my_data

            merged[!, :y8] = map(f -> Month(f).value, merged[!, :x])

            fname = @sprintf "gen_%d_class_CC_rating_%d_state_Texas.csv" id rating 

            path = joinpath("/projects", "emco4286", "data", "gads", "trajectories", "cc", fname)
            CSV.write(path, merged)
        end
    end

end
# Out:
# /projects/emco4286/data/gads/raw_data/gen_10034_type_851_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10035_type_851_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10036_type_852_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10037_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10038_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10039_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10040_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10041_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10042_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10056_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10057_type_852_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10066_type_852_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10067_type_851_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10068_type_851_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10086_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10087_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10088_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10089_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10162_type_850_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10240_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10351_type_851_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10352_type_851_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10353_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10369_type_861_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10370_type_861_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10371_type_861_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10372_type_861_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10373_type_861_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10374_type_861_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10375_type_862_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10376_type_862_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10377_type_862_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1037_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1038_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1039_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10474_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10475_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10477_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10478_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10491_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10492_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10493_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10494_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10495_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10496_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10809_type_800_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10810_type_800_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10840_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10841_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10842_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10843_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10844_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10845_type_861_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_10846_type_862_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11023_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11024_type_852_dtgrp_5_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11025_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11026_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11027_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11030_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11031_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11032_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11033_type_852_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11078_type_861_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11079_type_861_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11080_type_861_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11081_type_861_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11134_type_850_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11269_type_850_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11270_type_850_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11271_type_850_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11272_type_850_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11273_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11274_type_850_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11275_type_850_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11276_type_850_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11298_type_800_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11385_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11446_type_861_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11609_type_850_dtgrp_3_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11610_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11611_type_850_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11651_type_861_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11725_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11726_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11727_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11728_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11729_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11730_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11759_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11760_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11762_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11764_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11765_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11779_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11794_type_861_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11795_type_861_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11824_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11825_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11826_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11843_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11844_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11845_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11909_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11968_type_861_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11969_type_861_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11970_type_862_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11972_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11973_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_11974_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12140_type_860_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12155_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12156_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12157_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12158_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12159_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12160_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12217_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12218_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12219_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12221_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12222_type_851_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12228_type_800_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12238_type_851_dtgrp_5_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12250_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12600_type_850_dtgrp_6_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12769_type_862_dtgrp_6_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12770_type_861_dtgrp_6_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_12771_type_861_dtgrp_6_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1385_type_862_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1386_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1387_type_862_dtgrp_3_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1388_type_862_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1389_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1390_type_862_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1392_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1393_type_862_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1394_type_862_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1395_type_862_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1396_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1397_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1398_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1399_type_861_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1400_type_861_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1401_type_861_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1402_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1403_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1404_type_861_dtgrp_3_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1405_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1406_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1407_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1408_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1409_type_861_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1410_type_861_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1411_type_861_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1412_type_851_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1413_type_851_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1414_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1415_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1416_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1417_type_861_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1418_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1419_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1420_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1421_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1422_type_861_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1423_type_851_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1424_type_851_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1425_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1426_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1427_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1428_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1670_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_1671_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2004_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# ┌ Warning: thread = 1 warning: error parsing DateTime around row = 377, col = 1: "NULL,", error=INVALID: DELIMITED | INVALID_DELIMITER
# └ @ CSV /projects/emco4286/.julia/packages/CSV/XLcqT/src/file.jl:595
# /projects/emco4286/data/gads/raw_data/gen_2005_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# ┌ Warning: thread = 1 warning: error parsing DateTime around row = 371, col = 1: "NULL,", error=INVALID: DELIMITED | INVALID_DELIMITER
# └ @ CSV /projects/emco4286/.julia/packages/CSV/XLcqT/src/file.jl:595
# /projects/emco4286/data/gads/raw_data/gen_2006_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2007_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2011_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2012_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2013_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# ┌ Warning: thread = 1 warning: error parsing DateTime around row = 334, col = 1: "NULL,", error=INVALID: DELIMITED | INVALID_DELIMITER
# └ @ CSV /projects/emco4286/.julia/packages/CSV/XLcqT/src/file.jl:595
# /projects/emco4286/data/gads/raw_data/gen_2014_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# ┌ Warning: thread = 1 warning: error parsing DateTime around row = 331, col = 1: "NULL,", error=INVALID: DELIMITED | INVALID_DELIMITER
# └ @ CSV /projects/emco4286/.julia/packages/CSV/XLcqT/src/file.jl:595
# /projects/emco4286/data/gads/raw_data/gen_2016_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2017_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2019_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2208_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2209_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2210_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2211_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2212_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2213_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2214_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2215_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2238_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2244_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2245_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_2793_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4173_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4174_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4175_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4176_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4177_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4349_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4352_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4353_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4961_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4966_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_4967_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5591_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# ┌ Warning: thread = 1 warning: error parsing DateTime around row = 2100, col = 1: "NULL,", error=INVALID: DELIMITED | INVALID_DELIMITER
# └ @ CSV /projects/emco4286/.julia/packages/CSV/XLcqT/src/file.jl:595
# /projects/emco4286/data/gads/raw_data/gen_5592_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5593_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5594_type_850_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5853_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5854_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5855_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5856_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5857_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5858_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5859_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5860_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5873_type_852_dtgrp_3_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5874_type_852_dtgrp_3_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5875_type_860_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5876_type_860_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5910_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5911_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5912_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5913_type_852_dtgrp_5_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5914_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5915_type_851_dtgrp_5_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5922_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5923_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5924_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5925_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5926_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_5927_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_7467_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_7468_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_7469_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_7470_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8115_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8116_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8117_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8119_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8120_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8121_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8122_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_8124_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9178_type_852_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9179_type_851_dtgrp_4_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9552_type_851_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9553_type_852_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9554_type_851_dtgrp_4_rating_3_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9825_type_852_dtgrp_2_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9826_type_851_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9827_type_851_dtgrp_2_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9828_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9829_type_852_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9830_type_851_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9831_type_851_dtgrp_3_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9988_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9989_type_851_dtgrp_1_rating_1_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9990_type_852_dtgrp_1_rating_2_state_Texas_raw.csv
# /projects/emco4286/data/gads/raw_data/gen_9991_type_851_dtgrp_4_rating_1_state_Texas_raw.csv
